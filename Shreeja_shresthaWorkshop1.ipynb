# %%
# !pip install pillow
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)

# %%
from PIL import Image

# %%
image_colored= Image.open("/content/drive/MyDrive/AI and Machine Learning/hck.png")

# %%
print("Format:",image_colored.format)
print("Mode:",image_colored.mode)
print("Size:",image_colored.size)
# Out:
# Format: PNG
# Mode: P
# Size: (464, 108)

# %%
image_colored=image_colored.convert("RGB")
print(image_colored.mode)
# Out:
# RGB

# %%
image_grayed=image_colored.convert('L')
display(image_grayed)
# Out:
# <PIL.Image.Image image mode=L size=464x108>

# %%
print(image_grayed.size)
print(image_grayed.format)
print(image_grayed.mode)
# Out:
# (464, 108)
# None
# L

# %%
width,height=image_grayed.size
channels=len(image_grayed.getbands())
print(f"Image shape (gray):({height},{width},{channels})")
# Out:
# Image shape (gray):(108,464,1)

# %%
width,height=image_colored.size
channels=len(image_colored.getbands())
print(f"Image shape (gray):({height},{width},{channels})")
image_size_colored=width*height*3
print(f"Image size(RGB):{image_size_colored}")
# Out:
# Image shape (gray):(108,464,3)
# Image size(RGB):150336

# %%
import numpy as np
image_array_colored=np.array(image_colored)
image_array_colored.shape
# Out:
# (108, 464, 3)

# %%
image_array_grayed=np.array(image_grayed)
image_array_grayed.shape
# Out:
# (108, 464)

# %% [markdown]
# **Accessing Indivisual array**

# %%
red_channel=image_array_colored[:,:,0]#red channel
print(red_channel)
display(red_channel)
# Out:
# [[174 153 153 ... 255 255 255]
#  [153 111 113 ... 255 255 255]
#  [153 113 116 ... 255 255 255]
#  ...
#  [153 113 116 ... 255 255 255]
#  [153 113 116 ... 255 255 255]
#  [153 113 116 ... 255 255 255]]
# array([[174, 153, 153, ..., 255, 255, 255],
#        [153, 111, 113, ..., 255, 255, 255],
#        [153, 113, 116, ..., 255, 255, 255],
#        ...,
#        [153, 113, 116, ..., 255, 255, 255],
#        [153, 113, 116, ..., 255, 255, 255],
#        [153, 113, 116, ..., 255, 255, 255]], dtype=uint8)

# %%
red_channel=image_array_colored.copy()
red_channel[:,:,1]=0
red_channel[:,:,2]=0
print(red_channel)
display(red_channel)
# Out:
# [[[174   0   0]
#   [153   0   0]
#   [153   0   0]
#   ...
#   [255   0   0]
#   [255   0   0]
#   [255   0   0]]
#
#  [[153   0   0]
#   [111   0   0]
#   [113   0   0]
#   ...
#   [255   0   0]
#   [255   0   0]
#   [255   0   0]]
#
#  [[153   0   0]
#   [113   0   0]
#   [116   0   0]
#   ...
#   [255   0   0]
#   [255   0   0]
#   [255   0   0]]
#
#  ...
#
#  [[153   0   0]
#   [113   0   0]
#   [116   0   0]
#   ...
#   [255   0   0]
#   [255   0   0]
#   [255   0   0]]
#
#  [[153   0   0]
#   [113   0   0]
#   [116   0   0]
#   ...
#   [255   0   0]
#   [255   0   0]
#   [255   0   0]]
#
#  [[153   0   0]
#   [113   0   0]
#   [116   0   0]
#   ...
#   [255   0   0]
#   [255   0   0]
#   [255   0   0]]]
# array([[[174,   0,   0],
#         [153,   0,   0],
#         [153,   0,   0],
#         ...,
#         [255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0]],
#
#        [[153,   0,   0],
#         [111,   0,   0],
#         [113,   0,   0],
#         ...,
#         [255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0]],
#
#        [[153,   0,   0],
#         [113,   0,   0],
#         [116,   0,   0],
#         ...,
#         [255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0]],
#
#        ...,
#
#        [[153,   0,   0],
#         [113,   0,   0],
#         [116,   0,   0],
#         ...,
#         [255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0]],
#
#        [[153,   0,   0],
#         [113,   0,   0],
#         [116,   0,   0],
#         ...,
#         [255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0]],
#
#        [[153,   0,   0],
#         [113,   0,   0],
#         [116,   0,   0],
#         ...,
#         [255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0]]], dtype=uint8)

# %%
green_channel=image_array_colored.copy()
green_channel[:,:,0]=0
green_channel[:,:,2]=0
print(green_channel)
display(green_channel)
# Out:
# [[[  0 215   0]
#   [  0 208   0]
#   [  0 208   0]
#   ...
#   [  0 255   0]
#   [  0 255   0]
#   [  0 255   0]]
#
#  [[  0 208   0]
#   [  0 190   0]
#   [  0 191   0]
#   ...
#   [  0 255   0]
#   [  0 255   0]
#   [  0 255   0]]
#
#  [[  0 208   0]
#   [  0 191   0]
#   [  0 192   0]
#   ...
#   [  0 255   0]
#   [  0 255   0]
#   [  0 255   0]]
#
#  ...
#
#  [[  0 208   0]
#   [  0 191   0]
#   [  0 192   0]
#   ...
#   [  0 255   0]
#   [  0 255   0]
#   [  0 255   0]]
#
#  [[  0 208   0]
#   [  0 191   0]
#   [  0 192   0]
#   ...
#   [  0 255   0]
#   [  0 255   0]
#   [  0 255   0]]
#
#  [[  0 208   0]
#   [  0 191   0]
#   [  0 192   0]
#   ...
#   [  0 255   0]
#   [  0 255   0]
#   [  0 255   0]]]
# array([[[  0, 215,   0],
#         [  0, 208,   0],
#         [  0, 208,   0],
#         ...,
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]],
#
#        [[  0, 208,   0],
#         [  0, 190,   0],
#         [  0, 191,   0],
#         ...,
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]],
#
#        [[  0, 208,   0],
#         [  0, 191,   0],
#         [  0, 192,   0],
#         ...,
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]],
#
#        ...,
#
#        [[  0, 208,   0],
#         [  0, 191,   0],
#         [  0, 192,   0],
#         ...,
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]],
#
#        [[  0, 208,   0],
#         [  0, 191,   0],
#         [  0, 192,   0],
#         ...,
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]],
#
#        [[  0, 208,   0],
#         [  0, 191,   0],
#         [  0, 192,   0],
#         ...,
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]]], dtype=uint8)

# %%
b_channel=image_array_colored.copy()
b_channel[:,:,0]=0
b_channel[:,:,1]=0
print(b_channel)
display(b_channel)
# Out:
# [[[  0   0 150]
#   [  0   0 120]
#   [  0   0 120]
#   ...
#   [  0   0 255]
#   [  0   0 255]
#   [  0   0 255]]
#
#  [[  0   0 120]
#   [  0   0  58]
#   [  0   0  62]
#   ...
#   [  0   0 255]
#   [  0   0 255]
#   [  0   0 255]]
#
#  [[  0   0 120]
#   [  0   0  62]
#   [  0   0  67]
#   ...
#   [  0   0 255]
#   [  0   0 255]
#   [  0   0 255]]
#
#  ...
#
#  [[  0   0 120]
#   [  0   0  62]
#   [  0   0  67]
#   ...
#   [  0   0 255]
#   [  0   0 255]
#   [  0   0 255]]
#
#  [[  0   0 120]
#   [  0   0  62]
#   [  0   0  67]
#   ...
#   [  0   0 255]
#   [  0   0 255]
#   [  0   0 255]]
#
#  [[  0   0 120]
#   [  0   0  62]
#   [  0   0  67]
#   ...
#   [  0   0 255]
#   [  0   0 255]
#   [  0   0 255]]]
# array([[[  0,   0, 150],
#         [  0,   0, 120],
#         [  0,   0, 120],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]],
#
#        [[  0,   0, 120],
#         [  0,   0,  58],
#         [  0,   0,  62],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]],
#
#        [[  0,   0, 120],
#         [  0,   0,  62],
#         [  0,   0,  67],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]],
#
#        ...,
#
#        [[  0,   0, 120],
#         [  0,   0,  62],
#         [  0,   0,  67],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]],
#
#        [[  0,   0, 120],
#         [  0,   0,  62],
#         [  0,   0,  67],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]],
#
#        [[  0,   0, 120],
#         [  0,   0,  62],
#         [  0,   0,  67],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]]], dtype=uint8)

# %%
row_100=image_array_colored[100,:,:]
print(row_100)
display(row_100)
# Out:
# [[153 208 120]
#  [113 191  62]
#  [116 192  67]
#  ...
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]]
# array([[153, 208, 120],
#        [113, 191,  62],
#        [116, 192,  67],
#        ...,
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255]], dtype=uint8)

# %%
column_50=image_array_colored[:,50,:]
print(column_50)
display(column_50)
# Out:
# [[153 208 120]
#  [113 191  62]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [113 191  62]
#  [113 191  62]
#  [111 190  58]
#  [105 188  47]
#  [113 191  62]
#  [128 197  87]
#  [145 204 110]
#  [170 215 145]
#  [204 231 189]
#  [223 240 214]
#  [243 249 239]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [116 192  67]
#  [108 189  53]
#  [194 226 176]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]]
# array([[153, 208, 120],
#        [113, 191,  62],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [113, 191,  62],
#        [113, 191,  62],
#        [111, 190,  58],
#        [105, 188,  47],
#        [113, 191,  62],
#        [128, 197,  87],
#        [145, 204, 110],
#        [170, 215, 145],
#        [204, 231, 189],
#        [223, 240, 214],
#        [243, 249, 239],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [116, 192,  67],
#        [108, 189,  53],
#        [194, 226, 176],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255]], dtype=uint8)

# %%
pixel =image_array_colored[10,50,:]
print(pixel)
# Out:
# [116 192  67]

# %% [markdown]
# **Extracting Sub Images(Cropping Using PIL)**

# %%
left=100
upper=50
right=200
lower=150
croped_image=image_colored.crop((left,upper,right,lower))
display(croped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %% [markdown]
# **Saving Numpy Array to Image**

# %%
image_array=np.zeros((100,100,3),dtype=np.uint8)
image_from_array=Image.fromarray(image_array)
image_from_array.show()
display(image_from_array)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
image_from_array.save("output_image.jpg")

# %% [markdown]
# **PCA(on corelated space ma chai map gardinxa, direction unchanged(eigen value greater more important(no relation exist at all)**

# %% [markdown]
# PCA= each pixel acts as a feature
# covarience=gives relation between two feature
